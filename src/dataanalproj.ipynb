# %%
from GCDfns.gcd import gcd_basic, gcd_extended
from dataanalproj.levenshtein import levenshtein_distance

# %%
print(levenshtein_distance("kitten", "sitting"))
print(levenshtein_distance("kitten", "kitten"))
print(levenshtein_distance("here", "there"))
# Out:
# 3
# 0
# 1

# %%
print(gcd_basic(48, 27))
print(gcd_basic(0, 0))
print(gcd_basic(93, 53))
print(gcd_extended(48, 27))
# Out:
# 3
# 0
# 1
# (3, 4, -7)
